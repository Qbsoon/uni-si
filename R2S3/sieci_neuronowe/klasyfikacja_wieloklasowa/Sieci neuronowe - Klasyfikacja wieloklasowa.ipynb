# %% [markdown]
# # Uczenie maszynowe i sieci neuronowe

# %%
conda install keras
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/michal/anaconda3/envs/myenv
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          10 KB
#     keras-2.12.0               |  py311hca03da5_0         2.1 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     libgfortran-5.0.0          |11_3_0_hca03da5_28         142 KB
#     numpy-1.26.4               |  py311he598dae_0          12 KB
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   keras              pkgs/main/osx-arm64::keras-2.12.0-py311hca03da5_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.21-h269037a_0
#   numpy              pkgs/main/osx-arm64::numpy-1.26.4-py311he598dae_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.26.4-py311hfbfe69c_0
#   scipy              pkgs/main/osx-arm64::scipy-1.11.4-py311hc76d9b0_0
#
#
#
# Downloading and Extracting Packages:
# keras-2.12.0         | 2.1 MB    |                                       |   0%
# libgfortran-5.0.0    | 142 KB    |                                       |   0%
#
# keras-preprocessing- | 35 KB     |                                       |   0%
#
#
# numpy-1.26.4         | 12 KB     |                                       |   0%
#
#
#
# blas-1.0             | 10 KB     |                                       |   0%
# libgfortran-5.0.0    | 142 KB    | ####1                                 |  11%
# libgfortran-5.0.0    | 142 KB    | ############4                         |  34%
# libgfortran-5.0.0    | 142 KB    | ####################8                 |  56%
# keras-2.12.0         | 2.1 MB    | ##1                                   |   6%
#
# keras-preprocessing- | 35 KB     | ################9                     |  46%
# libgfortran-5.0.0    | 142 KB    | ##################################### | 100%
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
# libgfortran-5.0.0    | 142 KB    | ##################################### | 100%
#
#
#
# blas-1.0             | 10 KB     | ##################################### | 100%
#
#
#
# keras-2.12.0         | 2.1 MB    | #######2                              |  20%
#
# keras-preprocessing- | 35 KB     | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install tensorflow
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/michal/anaconda3/envs/myenv
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.2.0        |            eigen           3 KB
#     abseil-cpp-20211102.0      |       hc377ac9_0         933 KB
#     absl-py-1.4.0              |  py311hca03da5_0         240 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     cryptography-41.0.3        |  py311h3c57c4d_0         1.3 MB
#     cyrus-sasl-2.1.28          |       h458e800_1         222 KB
#     flatbuffers-2.0.0          |       hc377ac9_0         890 KB
#     gast-0.4.0                 |     pyhd3eb1b0_0          13 KB
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB
#     google-auth-oauthlib-0.5.2 |  py311hca03da5_0          30 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     grpc-cpp-1.48.2            |       h877324c_0         3.0 MB
#     grpcio-1.48.2              |  py311h877324c_0         752 KB
#     hdf5-1.12.1                |       h160e8cb_2         4.3 MB
#     icu-68.1                   |       hc377ac9_0        10.7 MB
#     krb5-1.20.1                |       h8380606_1         1.2 MB
#     libcurl-8.2.1              |       h0f1d93c_0         343 KB
#     libnghttp2-1.52.0          |       h10c0552_1         628 KB
#     libpq-12.15                |       h449679c_1         2.4 MB
#     libssh2-1.10.0             |       h449679c_2         289 KB
#     libxml2-2.10.4             |       h372ba2a_0         638 KB
#     mysql-5.7.24               |       he1ceea5_2        57.5 MB
#     numpy-1.23.5               |  py311hb2c0538_0          11 KB
#     numpy-base-1.23.5          |  py311h9eb1c70_0         6.1 MB
#     oauthlib-3.2.2             |  py311hca03da5_0         247 KB
#     openssl-1.1.1w             |       h1a28f6b_0         3.1 MB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     pyopenssl-23.2.0           |  py311hca03da5_0         126 KB
#     python-3.11.5              |       hc0d8a6c_0        15.4 MB
#     python-flatbuffers-2.0     |     pyhd3eb1b0_0          34 KB
#     qt-main-5.15.2             |       h8c8f68c_9        38.5 MB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     tensorboard-2.12.1         |  py311hca03da5_0         5.6 MB
#     tensorboard-data-server-0.7.0|  py311ha6e5c4f_0         3.5 MB
#     tensorboard-plugin-wit-1.8.1|  py311hca03da5_0         694 KB
#     tensorflow-2.12.0          |eigen_py311h689d69b_0           5 KB
#     tensorflow-base-2.12.0     |eigen_py311h0a52ebb_0       140.5 MB
#     tensorflow-estimator-2.12.0|  py311hca03da5_0         652 KB
#     termcolor-2.1.0            |  py311hca03da5_0          14 KB
#     wheel-0.35.1               |     pyhd3eb1b0_0          38 KB
#     ------------------------------------------------------------
#                                            Total:       299.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/osx-arm64::_tflow_select-2.2.0-eigen
#   abseil-cpp         pkgs/main/osx-arm64::abseil-cpp-20211102.0-hc377ac9_0
#   absl-py            pkgs/main/osx-arm64::absl-py-1.4.0-py311hca03da5_0
#   aiohttp            pkgs/main/osx-arm64::aiohttp-3.9.3-py311h80987f9_0
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   blinker            pkgs/main/osx-arm64::blinker-1.6.2-py311hca03da5_0
#   c-ares             pkgs/main/osx-arm64::c-ares-1.19.1-h80987f9_0
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   cryptography       pkgs/main/osx-arm64::cryptography-41.0.3-py311h3c57c4d_0
#   flatbuffers        pkgs/main/osx-arm64::flatbuffers-2.0.0-hc377ac9_0
#   frozenlist         pkgs/main/osx-arm64::frozenlist-1.4.0-py311h80987f9_0
#   gast               pkgs/main/noarch::gast-0.4.0-pyhd3eb1b0_0
#   giflib             pkgs/main/osx-arm64::giflib-5.2.1-h80987f9_3
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/osx-arm64::google-auth-oauthlib-0.5.2-py311hca03da5_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpc-cpp           pkgs/main/osx-arm64::grpc-cpp-1.48.2-h877324c_0
#   grpcio             pkgs/main/osx-arm64::grpcio-1.48.2-py311h877324c_0
#   h5py               pkgs/main/osx-arm64::h5py-3.9.0-py311hba6ad2f_0
#   hdf5               pkgs/main/osx-arm64::hdf5-1.12.1-h160e8cb_2
#   libcurl            pkgs/main/osx-arm64::libcurl-8.2.1-h0f1d93c_0
#   libev              pkgs/main/osx-arm64::libev-4.33-h1a28f6b_1
#   libnghttp2         pkgs/main/osx-arm64::libnghttp2-1.52.0-h10c0552_1
#   libprotobuf        pkgs/main/osx-arm64::libprotobuf-3.20.3-h514c7bf_0
#   libssh2            pkgs/main/osx-arm64::libssh2-1.10.0-h449679c_2
#   markdown           pkgs/main/osx-arm64::markdown-3.4.1-py311hca03da5_0
#   multidict          pkgs/main/osx-arm64::multidict-6.0.4-py311h80987f9_0
#   oauthlib           pkgs/main/osx-arm64::oauthlib-3.2.2-py311hca03da5_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   protobuf           pkgs/main/osx-arm64::protobuf-3.20.3-py311h313beb8_0
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   pyjwt              pkgs/main/osx-arm64::pyjwt-2.4.0-py311hca03da5_0
#   pyopenssl          pkgs/main/osx-arm64::pyopenssl-23.2.0-py311hca03da5_0
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-2.0-pyhd3eb1b0_0
#   re2                pkgs/main/osx-arm64::re2-2022.04.01-hc377ac9_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   snappy             pkgs/main/osx-arm64::snappy-1.1.10-h313beb8_1
#   tensorboard        pkgs/main/osx-arm64::tensorboard-2.12.1-py311hca03da5_0
#   tensorboard-data-~ pkgs/main/osx-arm64::tensorboard-data-server-0.7.0-py311ha6e5c4f_0
#   tensorboard-plugi~ pkgs/main/osx-arm64::tensorboard-plugin-wit-1.8.1-py311hca03da5_0
#   tensorflow         pkgs/main/osx-arm64::tensorflow-2.12.0-eigen_py311h689d69b_0
#   tensorflow-base    pkgs/main/osx-arm64::tensorflow-base-2.12.0-eigen_py311h0a52ebb_0
#   tensorflow-estima~ pkgs/main/osx-arm64::tensorflow-estimator-2.12.0-py311hca03da5_0
#   termcolor          pkgs/main/osx-arm64::termcolor-2.1.0-py311hca03da5_0
#   werkzeug           pkgs/main/osx-arm64::werkzeug-2.2.3-py311hca03da5_0
#   yarl               pkgs/main/osx-arm64::yarl-1.9.3-py311h80987f9_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   wheel              pkgs/main/osx-arm64::wheel-0.41.2-py3~ --> pkgs/main/noarch::wheel-0.35.1-pyhd3eb1b0_0
#
# The following packages will be DOWNGRADED:
#
#   cyrus-sasl                              2.1.28-h9131b1a_1 --> 2.1.28-h458e800_1
#   icu                                       73.1-h313beb8_0 --> 68.1-hc377ac9_0
#   krb5                                    1.20.1-hf3e1bf2_1 --> 1.20.1-h8380606_1
#   libpq                                    12.17-h02f6b3c_0 --> 12.15-h449679c_1
#   libxml2                                 2.10.4-h0dcf63f_1 --> 2.10.4-h372ba2a_0
#   mysql                                   5.7.24-ha71a6ea_2 --> 5.7.24-he1ceea5_2
#   numpy                              1.26.4-py311he598dae_0 --> 1.23.5-py311hb2c0538_0
#   numpy-base                         1.26.4-py311hfbfe69c_0 --> 1.23.5-py311h9eb1c70_0
#   openssl                                 3.0.13-h1a28f6b_0 --> 1.1.1w-h1a28f6b_0
#   python                                  3.11.8-hb885b13_0 --> 3.11.5-hc0d8a6c_0
#   qt-main                                5.15.2-h0917680_10 --> 5.15.2-h8c8f68c_9
#
#
#
# Downloading and Extracting Packages:
# tensorflow-base-2.12 | 140.5 MB  |                                       |   0%
# mysql-5.7.24         | 57.5 MB   |                                       |   0%
#
# qt-main-5.15.2       | 38.5 MB   |                                       |   0%
#
#
# python-3.11.5        | 15.4 MB   |                                       |   0%
#
#
#
# icu-68.1             | 10.7 MB   |                                       |   0%
#
#
#
#
# numpy-base-1.23.5    | 6.1 MB    |                                       |   0%
#
#
#
#
#
# tensorboard-2.12.1   | 5.6 MB    |                                       |   0%
#
#
#
#
#
#
# hdf5-1.12.1          | 4.3 MB    |                                       |   0%
#
#
#
#
#
#
#
# tensorboard-data-ser | 3.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libpq-12.15          | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 933 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# flatbuffers-2.0.0    | 890 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 752 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 694 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 652 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 638 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnghttp2-1.52.0    | 628 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.2.1        | 343 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.10.0       | 289 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.12 | 140.5 MB  |                                       |   0% [A
#
#
# python-3.11.5        | 15.4 MB   |                                       |   0%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 1                                     |   0%
# mysql-5.7.24         | 57.5 MB   |                                       |   0%
#
# qt-main-5.15.2       | 38.5 MB   |                                       |   0%
# mysql-5.7.24         | 57.5 MB   |                                       |   0%
#
#
# python-3.11.5        | 15.4 MB   | 3                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 1                                     |   0%
# mysql-5.7.24         | 57.5 MB   |                                       |   0%
#
#
#
# icu-68.1             | 10.7 MB   |                                       |   0%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 1                                     |   0%
#
# tensorflow-base-2.12 | 140.5 MB  | 2                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 2                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | 1                                     |   0%
# mysql-5.7.24         | 57.5 MB   |                                       |   0%
#
#
# python-3.11.5        | 15.4 MB   | 8                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | 1                                     |   0%
#
#
# python-3.11.5        | 15.4 MB   | #6                                    |   4%
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | 2                                     |   1%
# mysql-5.7.24         | 57.5 MB   | 1                                     |   0%
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | 3                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 3                                     |   1%
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
# mysql-5.7.24         | 57.5 MB   | 2                                     |   1%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | 4                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 3                                     |   1%
# mysql-5.7.24         | 57.5 MB   | 3                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 3                                     |   1%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 3                                     |   1%
# mysql-5.7.24         | 57.5 MB   | 3                                     |   1%
#
#
# python-3.11.5        | 15.4 MB   | ##1                                   |   6%
# tensorflow-base-2.12 | 140.5 MB  | 4                                     |   1%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 4                                     |   1%
#
#
# python-3.11.5        | 15.4 MB   | ##3                                   |   6%
# mysql-5.7.24         | 57.5 MB   | 4                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 4                                     |   1%
# tensorflow-base-2.12 | 140.5 MB  | 4                                     |   1%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   1%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   1%
#
#
# python-3.11.5        | 15.4 MB   | ##7                                   |   7%
# mysql-5.7.24         | 57.5 MB   | 6                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ##9                                   |   8%
#
# qt-main-5.15.2       | 38.5 MB   | 4                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | #7                                    |   5%
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | #8                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | 4                                     |   1%
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   1%
#
#
#
# icu-68.1             | 10.7 MB   | ##                                    |   5%
# mysql-5.7.24         | 57.5 MB   | 6                                     |   2%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 5                                     |   1%
# mysql-5.7.24         | 57.5 MB   | 7                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   1%
#
# qt-main-5.15.2       | 38.5 MB   | 5                                     |   1%
# mysql-5.7.24         | 57.5 MB   | 7                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###2                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | 5                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   2%
# mysql-5.7.24         | 57.5 MB   | 7                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###3                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | 5                                     |   2%
# mysql-5.7.24         | 57.5 MB   | 7                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 5                                     |   2%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ##4                                   |   7%
# mysql-5.7.24         | 57.5 MB   | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ##4                                   |   7%
# mysql-5.7.24         | 57.5 MB   | 8                                     |   2%
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###4                                  |   9%
#
#
#
# icu-68.1             | 10.7 MB   | ##5                                   |   7%
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ##6                                   |   7%
# mysql-5.7.24         | 57.5 MB   | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###5                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 5                                     |   2%
# mysql-5.7.24         | 57.5 MB   | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###5                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ##7                                   |   7%
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###6                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
# mysql-5.7.24         | 57.5 MB   | 9                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###6                                  |  10%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
# mysql-5.7.24         | 57.5 MB   | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###7                                  |  10%
# mysql-5.7.24         | 57.5 MB   | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###7                                  |  10%
# mysql-5.7.24         | 57.5 MB   | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ##9                                   |   8%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###7                                  |  10%
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ##9                                   |   8%
# mysql-5.7.24         | 57.5 MB   | #                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | ###8                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #                                     |   3%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###                                   |   8%
# mysql-5.7.24         | 57.5 MB   | #                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | ###9                                  |  11%
#
#
#
# icu-68.1             | 10.7 MB   | ###1                                  |   8%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ###9                                  |  11%
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###1                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ####                                  |  11%
# mysql-5.7.24         | 57.5 MB   | #1                                    |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ###2                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | 8                                     |   2%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###3                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | 8                                     |   2%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###3                                  |   9%
# mysql-5.7.24         | 57.5 MB   | #1                                    |   3%
#
#
# python-3.11.5        | 15.4 MB   | ####1                                 |  11%
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #1                                    |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ###4                                  |   9%
#
#
# python-3.11.5        | 15.4 MB   | ####1                                 |  11%
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###4                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ####2                                 |  11%
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###5                                  |  10%
# mysql-5.7.24         | 57.5 MB   | #2                                    |   3%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###6                                  |  10%
# mysql-5.7.24         | 57.5 MB   | #2                                    |   3%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###6                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #2                                    |   3%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 6                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | ####3                                 |  12%
# mysql-5.7.24         | 57.5 MB   | #2                                    |   4%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ####4                                 |  12%
# mysql-5.7.24         | 57.5 MB   | #3                                    |   4%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ###8                                  |  10%
#
#
# python-3.11.5        | 15.4 MB   | ####4                                 |  12%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   3%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###9                                  |  11%
#
#
# python-3.11.5        | 15.4 MB   | ####5                                 |  12%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ###9                                  |  11%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   3%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ####                                  |  11%
# mysql-5.7.24         | 57.5 MB   | #3                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ####5                                 |  12%
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ####                                  |  11%
# mysql-5.7.24         | 57.5 MB   | #3                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ####6                                 |  12%
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ####1                                 |  11%
# mysql-5.7.24         | 57.5 MB   | #4                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ####6                                 |  13%
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ####1                                 |  11%
# mysql-5.7.24         | 57.5 MB   | #4                                    |   4%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | ####7                                 |  13%
# mysql-5.7.24         | 57.5 MB   | #4                                    |   4%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | ####8                                 |  13%
# mysql-5.7.24         | 57.5 MB   | #4                                    |   4%
#
#
#
# icu-68.1             | 10.7 MB   | ####2                                 |  12%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ####3                                 |  12%
# mysql-5.7.24         | 57.5 MB   | #4                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ####8                                 |  13%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
# mysql-5.7.24         | 57.5 MB   | #5                                    |   4%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | ####9                                 |  13%
#
#
#
# icu-68.1             | 10.7 MB   | ####4                                 |  12%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ####4                                 |  12%
#
#
# python-3.11.5        | 15.4 MB   | ####9                                 |  13%
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
# python-3.11.5        | 15.4 MB   | #####                                 |  14%
#
#
#
# icu-68.1             | 10.7 MB   | ####5                                 |  12%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ####6                                 |  12%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####1                                |  14%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ####6                                 |  13%
# mysql-5.7.24         | 57.5 MB   | #6                                    |   4%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ####7                                 |  13%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #6                                    |   4%
#
#
#
# icu-68.1             | 10.7 MB   | ####7                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
# python-3.11.5        | 15.4 MB   | #####2                                |  14%
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #6                                    |   4%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ####8                                 |  13%
#
#
# python-3.11.5        | 15.4 MB   | #####2                                |  14%
# mysql-5.7.24         | 57.5 MB   | #6                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
# python-3.11.5        | 15.4 MB   | #####2                                |  14%
# mysql-5.7.24         | 57.5 MB   | #6                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #####3                                |  14%
# mysql-5.7.24         | 57.5 MB   | #6                                    |   5%
#
# tensorflow-base-2.12 | 140.5 MB  | 7                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | ####8                                 |  13%
#
#
# python-3.11.5        | 15.4 MB   | #####3                                |  14%
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
# python-3.11.5        | 15.4 MB   | #####4                                |  15%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #####4                                |  15%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | #####                                 |  14%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #####4                                |  15%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | #####                                 |  14%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
# python-3.11.5        | 15.4 MB   | #####5                                |  15%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #3                                    |   4%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #####5                                |  15%
#
#
#
# icu-68.1             | 10.7 MB   | #####2                                |  14%
# mysql-5.7.24         | 57.5 MB   | #7                                    |   5%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####6                                |  15%
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | #####2                                |  14%
#
#
# python-3.11.5        | 15.4 MB   | #####6                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | #3                                    |   4%
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####7                                |  15%
#
#
#
# icu-68.1             | 10.7 MB   | #####3                                |  14%
#
# qt-main-5.15.2       | 38.5 MB   | #3                                    |   4%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | #####3                                |  15%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #####7                                |  16%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####7                                |  16%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
#
# icu-68.1             | 10.7 MB   | #####4                                |  15%
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####8                                |  16%
#
#
#
# icu-68.1             | 10.7 MB   | #####4                                |  15%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####8                                |  16%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | #####5                                |  15%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #####8                                |  16%
#
#
#
# icu-68.1             | 10.7 MB   | #####5                                |  15%
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | #####6                                |  15%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | #####9                                |  16%
# mysql-5.7.24         | 57.5 MB   | #8                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | #####7                                |  16%
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ######                                |  16%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ######1                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ######2                               |  17%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ######3                               |  17%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ######3                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
# mysql-5.7.24         | 57.5 MB   | #9                                    |   5%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ######4                               |  17%
# mysql-5.7.24         | 57.5 MB   | ##                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | ######1                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
# python-3.11.5        | 15.4 MB   | ######4                               |  17%
# tensorflow-base-2.12 | 140.5 MB  | 8                                     |   2%
# mysql-5.7.24         | 57.5 MB   | ##                                    |   6%
#
#
# python-3.11.5        | 15.4 MB   | ######4                               |  18%
#
#
#
# icu-68.1             | 10.7 MB   | ######1                               |  17%
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   2%
# mysql-5.7.24         | 57.5 MB   | ##                                    |   6%
#
#
# python-3.11.5        | 15.4 MB   | ######5                               |  18%
# mysql-5.7.24         | 57.5 MB   | ##                                    |   6%
#
#
#
# icu-68.1             | 10.7 MB   | ######2                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   4%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ######6                               |  18%
# mysql-5.7.24         | 57.5 MB   | ##                                    |   6%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   4%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   4%
# mysql-5.7.24         | 57.5 MB   | ##1                                   |   6%
#
#
# python-3.11.5        | 15.4 MB   | ######6                               |  18%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   2%
#
#
# python-3.11.5        | 15.4 MB   | ######7                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | ######3                               |  17%
# mysql-5.7.24         | 57.5 MB   | ##1                                   |   6%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | ######7                               |  18%
#
#
#
# icu-68.1             | 10.7 MB   | ######4                               |  17%
# mysql-5.7.24         | 57.5 MB   | ##1                                   |   6%
#
#
# python-3.11.5        | 15.4 MB   | ######8                               |  18%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   2%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | ######5                               |  18%
# mysql-5.7.24         | 57.5 MB   | ##1                                   |   6%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
# mysql-5.7.24         | 57.5 MB   | ##1                                   |   6%
#
# qt-main-5.15.2       | 38.5 MB   | #7                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | ######9                               |  19%
#
#
#
# icu-68.1             | 10.7 MB   | ######5                               |  18%
#
#
# python-3.11.5        | 15.4 MB   | ######9                               |  19%
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
# mysql-5.7.24         | 57.5 MB   | ##1                                   |   6%
#
#
# python-3.11.5        | 15.4 MB   | ######9                               |  19%
#
#
#
# icu-68.1             | 10.7 MB   | ######6                               |  18%
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
# mysql-5.7.24         | 57.5 MB   | ##2                                   |   6%
#
#
#
# icu-68.1             | 10.7 MB   | ######6                               |  18%
#
#
# python-3.11.5        | 15.4 MB   | #######                               |  19%
#
# qt-main-5.15.2       | 38.5 MB   | #7                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #######                               |  19%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | ######7                               |  18%
#
#
# python-3.11.5        | 15.4 MB   | #######1                              |  19%
#
# qt-main-5.15.2       | 38.5 MB   | #7                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #######1                              |  19%
# mysql-5.7.24         | 57.5 MB   | ##2                                   |   6%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | #7                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | ######8                               |  18%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | #######2                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #######2                              |  20%
#
#
#
# icu-68.1             | 10.7 MB   | ######8                               |  19%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #######3                              |  20%
#
#
#
# icu-68.1             | 10.7 MB   | ######9                               |  19%
# mysql-5.7.24         | 57.5 MB   | ##3                                   |   6%
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | #######4                              |  20%
#
#
#
# icu-68.1             | 10.7 MB   | ######9                               |  19%
# mysql-5.7.24         | 57.5 MB   | ##3                                   |   6%
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | #######                               |  19%
#
#
# python-3.11.5        | 15.4 MB   | #######5                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | #######1                              |  19%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
# mysql-5.7.24         | 57.5 MB   | ##3                                   |   6%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
# python-3.11.5        | 15.4 MB   | #######6                              |  21%
#
#
#
# icu-68.1             | 10.7 MB   | #######1                              |  19%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | #######2                              |  19%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
# mysql-5.7.24         | 57.5 MB   | ##4                                   |   7%
#
#
#
# icu-68.1             | 10.7 MB   | #######2                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
# mysql-5.7.24         | 57.5 MB   | ##4                                   |   7%
#
#
#
# icu-68.1             | 10.7 MB   | #######3                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #######8                              |  21%
#
#
#
# icu-68.1             | 10.7 MB   | #######3                              |  20%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
#
# icu-68.1             | 10.7 MB   | #######4                              |  20%
# mysql-5.7.24         | 57.5 MB   | ##4                                   |   7%
#
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | #######4                              |  20%
# mysql-5.7.24         | 57.5 MB   | ##4                                   |   7%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
# python-3.11.5        | 15.4 MB   | #######9                              |  22%
#
#
# python-3.11.5        | 15.4 MB   | ########                              |  22%
#
#
#
# icu-68.1             | 10.7 MB   | #######5                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
# tensorflow-base-2.12 | 140.5 MB  | 9                                     |   3%
#
#
#
# icu-68.1             | 10.7 MB   | #######5                              |  21%
#
#
# python-3.11.5        | 15.4 MB   | ########1                             |  22%
#
# tensorflow-base-2.12 | 140.5 MB  | #                                     |   3%
# mysql-5.7.24         | 57.5 MB   | ##5                                   |   7%
#
#
#
# tensorflow-base-2.12 | 140.5 MB  | #                                     |   3%
#
# ...
# tensorflow-base-2.12 | 140.5 MB  | ##########5                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########5                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########5                           |  29%
# mysql-5.7.24         | 57.5 MB   | #################################8    |  92%
# tensorflow-base-2.12 | 140.5 MB  | ##########5                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########6                           |  29%
# mysql-5.7.24         | 57.5 MB   | ##################################2   |  93%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# mysql-5.7.24         | 57.5 MB   | ##################################3   |  93%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########7                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# mysql-5.7.24         | 57.5 MB   | ##################################8   |  94%
# tensorflow-base-2.12 | 140.5 MB  | ##########8                           |  29%
# tensorflow-base-2.12 | 140.5 MB  | ##########9                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ##########9                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ##########9                           |  30%
# mysql-5.7.24         | 57.5 MB   | ##################################9   |  94%
# tensorflow-base-2.12 | 140.5 MB  | ##########9                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# mysql-5.7.24         | 57.5 MB   | ###################################   |  95%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########                           |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# mysql-5.7.24         | 57.5 MB   | ###################################1  |  95%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# mysql-5.7.24         | 57.5 MB   | ###################################2  |  95%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########1                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########2                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########2                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########2                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########2                          |  30%
# tensorflow-base-2.12 | 140.5 MB  | ###########2                          |  30%
# mysql-5.7.24         | 57.5 MB   | ###################################3  |  96%
# mysql-5.7.24         | 57.5 MB   | ###################################3  |  96%
# tensorflow-base-2.12 | 140.5 MB  | ###########3                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########3                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########3                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########3                          |  31%
# mysql-5.7.24         | 57.5 MB   | ###################################4  |  96%
# tensorflow-base-2.12 | 140.5 MB  | ###########3                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########4                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########4                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########4                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########4                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########4                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########4                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# mysql-5.7.24         | 57.5 MB   | ###################################6  |  96%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########5                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# mysql-5.7.24         | 57.5 MB   | ###################################7  |  97%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# mysql-5.7.24         | 57.5 MB   | ###################################8  |  97%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  31%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# mysql-5.7.24         | 57.5 MB   | ###################################8  |  97%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# mysql-5.7.24         | 57.5 MB   | ###################################9  |  97%
# tensorflow-base-2.12 | 140.5 MB  | ###########6                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########7                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# mysql-5.7.24         | 57.5 MB   | ####################################2 |  98%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########8                          |  32%
# mysql-5.7.24         | 57.5 MB   | ####################################4 |  98%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# mysql-5.7.24         | 57.5 MB   | ####################################6 |  99%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ###########9                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  32%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# mysql-5.7.24         | 57.5 MB   | ####################################9 | 100%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############                          |  33%
# tensorflow-base-2.12 | 140.5 MB  | ############1                         |  33%
# mysql-5.7.24         | 57.5 MB   | ####################################9 | 100%
# tensorflow-base-2.12 | 140.5 MB  | ############2                         |  33%
# mysql-5.7.24         | 57.5 MB   | ##################################### | 100%
# tensorflow-base-2.12 | 140.5 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
keras.__version__
# Out:
# '3.7.0'

# %% [markdown]
# # Przykład klasyfikacji wieloklasowej: klasyfikacja krótkich artykułów prasowych
#
#
# W poprzedniej części przedstawiliśmy klasyfikację wektorów przy podziale na dwie rozłączne klasy za pomocą ściśle połączonej sieci neuronowej. Co się dzieje, gdy mamy więcej klas?
#
# W tej części zbudujemy sieć klasyfikującą doniesienia prasowe Agencji Reutera na 46 niezależnych tematów. Podział ma być dokonany na wiele grup, a więc mamy tym razem do czynienia z problemem klasyfikacji wieloklasowej. Każdy element zbioru danych może być przypisany tylko do jednej kategorii, a więc problem ten możemy określić mianem jednoetykietowej klasyfikacji wieloklasowej. Gdyby element zbioru danych mógł należeć jednocześnie do wielu kategorii (w tym przypadku do wielu tematów), to mielibyśmy do czynienia z problemem wieloetykietowej klasyfikacji wieloklasowej.

# %% [markdown]
# ## Zbiór danych Agencji Reutera
#
#
# W tej części będziemy pracować nad zbiorem danych Agencji Reutera — zestawem krótkich informacji prasowych dotyczących określonego tematu, które zostały opublikowane przez tę agencję w 1986 r. Jest to prosty i popularny zbiór danych, doskonale nadający się do eksperymentowania z klasyfikacją tekstu. Zbiór ten zawiera 46 różnych tematów. Do niektórych z nich należy o wiele więcej informacji prasowych niż do innych, ale każdy z tematów ma przynajmniej 10 przykładów w treningowym zbiorze danych.
#
# Zbiór Agencji Reutera, podobnie jak zbiory IMDB i MNIST, wchodzi w skład pakietu Keras. Przyjrzyjmy się jego zawartości.

# %%
from tensorflow.keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# %% [markdown]
# Podobnie jak w przypadku zbioru IMDB stosujemy argument num_words=10000, który ogranicza nasze działania do 10 000 słów występujących najczęściej w analizowanym zbiorze danych.
#
# Dysponujemy 8982 przykładami treningowymi i 2246 przykładami testowymi:

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %% [markdown]
# Każdy przykład jest listą wartości całkowitoliczbowych (indeksów słów) — takie samo rozwiązanie zostało zaprezentowane w przykładzie zbioru IMDB:

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# Poniższy kod umożliwia odkodowanie słów (możesz go uruchomić w celu zaspokojenia swojej ciekawości dotyczącej treści).

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
# Kod dekodujący recenzję. Zauważ, że indeksy są przesunięte o 3, ponieważ pod indeksami o numerach 0, 1 i 2 
# znajdują się indeksy symbolizujące „wypełnienie”, „początek sekwencji” i „nieznane słowo”.
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])

# %%
decoded_newswire
# Out:
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %% [markdown]
# Tabela etykiet przykładów zawiera wartości całkowitoliczbowe znajdujące się w zakresie od 0 do 45 (są to indeksy tematów):

# %%
train_labels[:45]
# Out:
# array([ 3,  4,  3,  4,  4,  4,  4,  3,  3, 16,  3,  3,  4,  4, 19,  8, 16,
#         3,  3, 21, 11,  4,  4,  3,  3,  1,  3,  1,  3, 16,  1,  4, 13, 20,
#         1,  4,  4, 11,  3,  3,  3, 11, 16,  4,  4])

# %% [markdown]
# ## Przygotowywanie danych
#
# Dane możemy zamienić na wektory za pomocą tego samego kodu, z którego korzystaliśmy w poprzednim przykładzie.

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Zbiór treningowy w postaci wektora.
x_train = vectorize_sequences(train_data)
# Zbiór testowy w postaci wektora.
x_test = vectorize_sequences(test_data)

# %% [markdown]
# Operację przekształcania etykiet na wektor można przeprowadzić na dwa sposoby: poprzez rzutowanie listy etykiet na tensor wartości całkowitoliczbowych lub poprzez kodowanie z gorącą jedynką. Kodowanie z gorącą jedynką jest używane zwykle w przypadku danych kategorialnych — często określa się je mianem kodowania kategorialnego. W tym przypadku kodowanie z gorącą jedynką przeprowadzone na zbiorze etykiet będzie polegało na osadzeniu każdej etykiety w formie wektora wypełnionego samymi zerami z liczbą 1 umieszczoną w miejscu indeksu etykiety. Przyjrzyj się kodowi implementującemu ten sposób kodowania:

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results

# Etykiety zbioru treningowego w postaci wektora.
one_hot_train_labels = to_one_hot(train_labels)
# Etykiety zbioru testowego w postaci wektora.
one_hot_test_labels = to_one_hot(test_labels)

# %% [markdown]
# Operację tę można wykonać za pomocą kodu wbudowanego w pakiet Keras (jego działanie widzieliśmy już podczas pracy nad zbiorem MNIST):

# %%
from tensorflow.keras.utils import to_categorical

one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %% [markdown]
# ## Budowanie sieci
#
#
# Problem klasyfikacji tematów przypomina nieco problem klasyfikacji recenzji filmów: w obu sytuacjach próbujemy dokonać klasyfikacji krótkiego fragmentu tekstu. Tym razem mamy dodatkowe ograniczenie: liczba klas wyjściowych wzrosła z 2 do 46. W związku z tym przestrzeń wyjściowa ma o wiele więcej wymiarów.
#
# W przypadku stosowanego wcześniej stosu warstw Dense każda warstwa ma dostęp tylko do informacji wygenerowanych przez poprzednią warstwę. Jeżeli jakaś informacja ważna z punktu widzenia klasyfikacji zostanie pominięta przez którąś z warstw, to nie ma możliwości jej odzyskania przez kolejne warstwy. Każda warstwa może potencjalnie stać się informacyjnym wąskim gardłem. W poprzednim przykładzie stosowaliśmy warstwy pośrednie o 16 wymiarach, ale przestrzeń 16 wymiarów może być zbyt ograniczona, aby nauczyć się rozdzielania danych na 46 różnych klas. Tak małe warstwy mogą stać się wąskimi gardłami, przez które nie będą przechodziły dalej ważne informacje.
#
# W związku z tym będziemy tworzyli większe warstwy. Zacznijmy od 64 jednostek.

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(x_test.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))
# Out:
# /SI/si/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-01-20 22:12:06.971257: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (100)

# %% [markdown]
# Warto zwrócić uwagę na jeszcze dwie rzeczy związane z tą architekturą:
#
# * Sieć jest zakończona warstwą Dense o rozmiarze równym 46. W związku z tym każda próbka danych wejściowych spowoduje wygenerowanie przez sieć wektora o 46 wymiarach. Każdy element tego wektora (każdy jego wymiar) będzie zawierał informację odwołującą się do innej klasy.
# * W ostatniej warstwie zastosowano funkcję aktywacji softmax. Rozwiązanie to widzieliśmy w przykładzie zbioru MNIST. Dzięki niemu sieć będzie zwracała rozkład prawdopodobieństwa 46 różnych klas — dla każdej próbki wejściowej sieć wygeneruje 46-wymiarowy wektor wyjściowy, w którym element output[i] jest prawdopodobieństwem tego, że próbka należy do klasy i. Wszystkie 46 wyników po zsumowaniu da wartość 1.
#
# W tej sytuacji najlepiej jest skorzystać z funkcji straty w postaci kategorialnej entropii krzyżowej (categorical_crossentropy). Funkcja ta mierzy odległość między dwoma rozkładami prawdopodobieństw: rozkładem prawdopodobieństw zwróconych przez sieć i rozkładem prawdopodobieństw określanym przez etykiety. Minimalizacja odległości między tymi rozkładami pozwala na trenowanie sieci w celu zwracania wartości jak najbardziej zbliżonych do prawdziwych etykiet.

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Walidacja modelu
#
# Odłączmy 1000 próbek od treningowego zbioru danych w celu użycia ich w charakterze zbioru kontrolnego.

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %% [markdown]
# Czas uruchomić trenowanie sieci trwające 20 epok.

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4304 - loss: 3.1114 - val_accuracy: 0.6310 - val_loss: 1.7719
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6745 - loss: 1.5671 - val_accuracy: 0.7110 - val_loss: 1.3438
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7558 - loss: 1.1666 - val_accuracy: 0.7500 - val_loss: 1.1683
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7957 - loss: 0.9489 - val_accuracy: 0.7660 - val_loss: 1.0717
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8320 - loss: 0.7587 - val_accuracy: 0.7730 - val_loss: 1.0166
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8608 - loss: 0.6425 - val_accuracy: 0.7840 - val_loss: 0.9606
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8777 - loss: 0.5445 - val_accuracy: 0.7960 - val_loss: 0.9305
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9020 - loss: 0.4414 - val_accuracy: 0.8060 - val_loss: 0.9226
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9203 - loss: 0.3816 - val_accuracy: 0.8070 - val_loss: 0.8824
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9337 - loss: 0.3185 - val_accuracy: 0.8130 - val_loss: 0.8725
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9423 - loss: 0.2775 - val_accuracy: 0.8190 - val_loss: 0.8625
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9476 - loss: 0.2348 - val_accuracy: 0.8080 - val_loss: 0.9083
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9528 - loss: 0.2034 - val_accuracy: 0.8060 - val_loss: 0.9257
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9539 - loss: 0.1871 - val_accuracy: 0.8190 - val_loss: 0.8790
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9533 - loss: 0.1743 - val_accuracy: 0.8080 - val_loss: 0.9340
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9615 - loss: 0.1503 - val_accuracy: 0.8020 - val_loss: 0.9366
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9620 - loss: 0.1418 - val_accuracy: 0.8160 - val_loss: 0.9283
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9599 - loss: 0.1318 - val_accuracy: 0.8190 - val_loss: 0.9132
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9601 - loss: 0.1316 - val_accuracy: 0.8170 - val_loss: 0.9218
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9605 - loss: 0.1215 - val_accuracy: 0.8180 - val_loss: 0.9390

# %% [markdown]
# Teraz możemy wyświetlić wykresy krzywych strat i dokładności :

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Strata trenowania')
plt.plot(epochs, val_loss, 'b', label='Strata walidacji')
plt.title('Strata trenowania i walidacji')
plt.xlabel('Epoki')
plt.ylabel('Strata')
plt.legend()

plt.show()

# %%
plt.clf()   # Czyszczenie rysunku.

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Dokladnosc trenowania')
plt.plot(epochs, val_acc, 'b', label='Dokladnosc walidacji')
plt.title('Dokladnosc trenowania i walidacji')
plt.xlabel('Epoki')
plt.ylabel('Dokładność')
plt.legend()

plt.show()

# %% [markdown]
# Po dziewięciu epokach sieć zaczyna ulegać przeuczeniu. Spróbujmy uruchomić jeszcze raz proces uczenia sieci, ale tym razem ograniczymy jego działanie do 9 epok. Następnie sprawdzimy działanie sieci na testowym zbiorze danych.

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(partial_x_train,
          partial_y_train,
          epochs=8,
          batch_size=512,
          validation_data=(x_val, y_val))
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# /SI/si/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.3437 - loss: 3.2407 - val_accuracy: 0.6190 - val_loss: 1.8718
# Epoch 2/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6615 - loss: 1.6959 - val_accuracy: 0.6890 - val_loss: 1.4175
# Epoch 3/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7276 - loss: 1.2533 - val_accuracy: 0.7310 - val_loss: 1.2120
# Epoch 4/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7857 - loss: 1.0021 - val_accuracy: 0.7390 - val_loss: 1.1092
# Epoch 5/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8195 - loss: 0.8248 - val_accuracy: 0.7690 - val_loss: 1.0389
# Epoch 6/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8496 - loss: 0.6921 - val_accuracy: 0.7950 - val_loss: 0.9868
# Epoch 7/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8773 - loss: 0.5961 - val_accuracy: 0.8120 - val_loss: 0.9494
# Epoch 8/8
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8942 - loss: 0.4924 - val_accuracy: 0.8060 - val_loss: 0.9198
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7911 - loss: 0.9606

# %%
results
# Out:
# [0.9821953177452087, 0.7845057845115662]

# %% [markdown]
# Uzyskaliśmy dokładność na poziomie zbliżonym do 80%. W wyważonej klasyfikacji binarnej losowy klasyfikator uzyskałby wynik 50%, ale w tym przypadku jego wynik byłby zbliżony do 19%. Dokładność naszego klasyfikatora wydaje się całkiem dobra, jeżeli porówna się ją z klasyfikatorem przyporządkowującym etykiety w sposób losowy:

# %%
import copy

test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
float(np.sum(np.array(test_labels) == np.array(test_labels_copy))) / len(test_labels)
# Out:
# 0.195013357079252

# %% [markdown]
# ## Generowanie przewidywań dotyczących nowych danych
#
# Możemy zweryfikować zwracanie przez metodę predict naszej instancji modelu rozkładu prawdopodobieństwa wszystkich 46 tematów. Wygenerujmy przewidywania dla wszystkich elementów testowego zbioru danych.

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %% [markdown]
# Każdy element zmiennej predictions jest wektorem o długości równej 46:

# %%
predictions[0].shape
# Out:
# (46,)

# %% [markdown]
# Suma wszystkich wartości tego wektora wynosi 1:

# %%
np.sum(predictions[0])
# Out:
# np.float32(0.9999999)

# %% [markdown]
# Najwyższa wartość wektora wskazuje przewidywaną klasę — klasę, do której najprawdopodobniej należy dana próbka:

# %%
np.argmax(predictions[0])
# Out:
# np.int64(3)

# %% [markdown]
# ## Inne sposoby obsługi etykiet i funkcji straty
#
# Wcześniej było o tym, że drugim sposobem kodowania etykiet jest rzutowanie ich jako tensory całkowitoliczbowe w następujący sposób:

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
x_test.shape
# Out:
# (2246, 10000)

# %%
y_test.shape
# Out:
# (2246,)

# %% [markdown]
# Skorzystanie z tego rozwiązania wymaga wprowadzenia jednej zmiany w modelu — wybrania innej funkcji straty. W poprzednich przykładch wybraliśmy funkcje categorical_crossentropy, która wymaga podawania etykiet zakodowanych kategorialnie. Przy etykietach mających postać liczb całkowitych powinniśmy użyć funkcji sparse_categorical_crossentropy:

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
#
# NameError: name 'model' is not defined

# %% [markdown]
# Nowa funkcja straty z punktu widzenia matematyki działa tak samo jak funkcja categorical_crossentropy, ale wyposażono ją w inny interfejs.

# %% [markdown]
# ## Dlaczego warto tworzyć odpowiednio duże warstwy pośrednie?
#
#
# Stwierdziliśmy wcześniej, że sieć generuje dane wyjściowe mające 46 wymiarów, a więc powinniśmy unikać warstw pośrednich mających mniej niż 46 ukrytych jednostek. Sprawdźmy, co się stanie, jeżeli wprowadzimy do sieci takie informacyjne wąskie gardło. Wprowadźmy do sieci warstwy pośrednie mające mniej niż 46 wymiarów: zacznijmy od przykładowej warstwy z 4 wymiarami.

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
model.evaluate(x_test, one_hot_test_labels)
# Out:
# /SI/si/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.2086 - loss: 3.3721 - val_accuracy: 0.2240 - val_loss: 2.6941
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2428 - loss: 2.4660 - val_accuracy: 0.5560 - val_loss: 2.0196
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5847 - loss: 1.7994 - val_accuracy: 0.6130 - val_loss: 1.6523
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6277 - loss: 1.4838 - val_accuracy: 0.6170 - val_loss: 1.5649
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6405 - loss: 1.3466 - val_accuracy: 0.6240 - val_loss: 1.5101
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6682 - loss: 1.2143 - val_accuracy: 0.6440 - val_loss: 1.4745
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6864 - loss: 1.1673 - val_accuracy: 0.6500 - val_loss: 1.4502
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7073 - loss: 1.0827 - val_accuracy: 0.6500 - val_loss: 1.4604
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7254 - loss: 1.0271 - val_accuracy: 0.6640 - val_loss: 1.4312
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7523 - loss: 0.9643 - val_accuracy: 0.6720 - val_loss: 1.4655
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7609 - loss: 0.9169 - val_accuracy: 0.6590 - val_loss: 1.4955
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7686 - loss: 0.8881 - val_accuracy: 0.6690 - val_loss: 1.4911
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7730 - loss: 0.8581 - val_accuracy: 0.6730 - val_loss: 1.5547
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7779 - loss: 0.8141 - val_accuracy: 0.6690 - val_loss: 1.5694
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7844 - loss: 0.7842 - val_accuracy: 0.6750 - val_loss: 1.5900
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7860 - loss: 0.7854 - val_accuracy: 0.6780 - val_loss: 1.6206
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7936 - loss: 0.7377 - val_accuracy: 0.6840 - val_loss: 1.6354
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7929 - loss: 0.7255 - val_accuracy: 0.6810 - val_loss: 1.6907
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7929 - loss: 0.7084 - val_accuracy: 0.6800 - val_loss: 1.7303
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7930 - loss: 0.7086 - val_accuracy: 0.6860 - val_loss: 1.7557
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6838 - loss: 1.8418
# [1.8186731338500977, 0.6687444448471069]

# %% [markdown]
# Dokładność sieci w procesie walidacji osiąga teraz wartość szczytową na poziomie około 71%, a więc dokładność spadła w skali bezwzględnej o 8%. Wynika to głównie z tego, że sieć stara się skompresować wiele informacji w zbyt małej liczbie wymiarów warstwy pośredniej. Co prawda sieć jest w stanie dokonać podziału na 46 klas, a więc może ona zakodować większość niezbędnych informacji w formie ośmiowymiarowych reprezentacji, ale przestrzeń taka jest zbyt mała, aby umieścić w niej wszystkie informacje.

# %% [markdown]
# ## Dalsze eksperymenty
#
# * Spróbuj tworzyć większe lub mniejsze warstwy: warstwy zawierające np. po 32 lub 128 jednostek.
# * Korzystaliśmy z dwóch ukrytych warstw. Spróbuj utworzyć sieć zawierającą jedną taką warstwę, a następnie sieć składającą się z trzech lub więcej takich warstw.

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='leaky_relu', input_shape=(10000,)))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4863 - loss: 2.7914 - val_accuracy: 0.7080 - val_loss: 1.3482
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7695 - loss: 1.1081 - val_accuracy: 0.8000 - val_loss: 1.0102
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8731 - loss: 0.6511 - val_accuracy: 0.8250 - val_loss: 0.8795
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9192 - loss: 0.4223 - val_accuracy: 0.8250 - val_loss: 0.8317
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9418 - loss: 0.3129 - val_accuracy: 0.8300 - val_loss: 0.8219
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9515 - loss: 0.2240 - val_accuracy: 0.8240 - val_loss: 0.8299
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9572 - loss: 0.1877 - val_accuracy: 0.8320 - val_loss: 0.8419
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9561 - loss: 0.1654 - val_accuracy: 0.8200 - val_loss: 0.8595
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9581 - loss: 0.1514 - val_accuracy: 0.8220 - val_loss: 0.8651
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9624 - loss: 0.1290 - val_accuracy: 0.8230 - val_loss: 0.8839
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9607 - loss: 0.1228 - val_accuracy: 0.8220 - val_loss: 0.8926
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9598 - loss: 0.1255 - val_accuracy: 0.8090 - val_loss: 0.9200
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9631 - loss: 0.1030 - val_accuracy: 0.8180 - val_loss: 0.9172
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9647 - loss: 0.1015 - val_accuracy: 0.8150 - val_loss: 0.9280
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9605 - loss: 0.1059 - val_accuracy: 0.8170 - val_loss: 0.9497
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9613 - loss: 0.1129 - val_accuracy: 0.8110 - val_loss: 0.9572
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9586 - loss: 0.1032 - val_accuracy: 0.8190 - val_loss: 0.9534
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9676 - loss: 0.1048 - val_accuracy: 0.8130 - val_loss: 0.9808
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9588 - loss: 0.1047 - val_accuracy: 0.8110 - val_loss: 0.9849
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9666 - loss: 0.0913 - val_accuracy: 0.8100 - val_loss: 0.9941

# %% [markdown]
# ## Wnioski
#
#
# Oto wnioski, które należy wynieść z tego przykładu:
#
# * Podczas klasyfikacji danych na N klas sieć powinna kończyć się warstwą Dense o rozmiarze równym N.
# * W razie wystąpienia problemu wieloklasowej klasyfikacji elementów opisywanych przy użyciu jednej etykiety sieć powinna kończyć się funkcją aktywacji softmax, która umożliwi wygenerowanie rozkładu wartości prawdopodobieństw N klas.
# * Kategorialna entropia krzyżowa jest prawie zawsze funkcją straty, która powinna być używana podczas pracy z tego typu problemami. Minimalizuje ona odległość między rozkładem prawdopodobieństwa wygenerowanym przez sieć a rozkładem wartości docelowych.
# * Podczas klasyfikacji wieloklasowej można korzystać z jednego z dwóch sposobów obsługi etykiet:
#
#     * Kodowania etykiet za pomocą kodowania kategorycznego(kodowania z gorącą jedynką)i używania funkcji categorical_crossentropy jako funkcji straty.*
#     * Kodowania etykiet za pomocą wartości całkowitoliczbowych i używania funkcji sparse_categorical_crossentropy jako funkcji straty.*
#
#
# * Jeżeli musisz podzielić dane na dużą liczbę kategorii, to staraj się unikać tworzenia wąskich gardeł blokujących przepływ informacji w postaci zbyt małych warstw pośrednich.

# %% [markdown]
# ## Zadania do wykonania
#
# 1. Uzupełnić materiały o własne przemyślenia, wnioski, grafiki, schematy...
#
# 2. Wykonać ćwiczenia z sekcji `dalsze eksperymenty`

# %% [markdown]
# Trochę przemyśleń już napisałem w pliku klasyfikacji binarnej, ale nie zamieściłem tam żadnych grafik, więc tutaj dla odmiany zamieściłem kilka różnych modeli i przedstawiam ich straty oraz dokładności na łączonym wykresie dla porównania.

# %%
from IPython.display import clear_output
import tensorflow as tf
model = models.Sequential()
model.add(layers.Input(shape=(10000,)))
model.add(layers.Dense(86, activation='leaky_relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history1 = model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
clear_output()

# %%
model = models.Sequential()
model.add(layers.Dense(128, activation='leaky_relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='leaky_relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history2 = model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
clear_output()

# %%
model = models.Sequential()
model.add(layers.Dense(256, activation='leaky_relu', input_shape=(10000,)))
model.add(layers.Dense(128, activation='leaky_relu'))
model.add(layers.Dense(64, activation='leaky_relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history3 = model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
clear_output()

# %%
model = models.Sequential()
model.add(layers.Dense(92, activation='leaky_relu', input_shape=(10000,)))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history4 = model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
clear_output()

# %%
loss1 = history1.history['loss']
loss2 = history2.history['loss']
loss3 = history3.history['loss']
loss4 = history4.history['loss']
val_loss1 = history1.history['val_loss']
val_loss2 = history2.history['val_loss']
val_loss3 = history3.history['val_loss']
val_loss4 = history4.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss1, 'bo', label='Model 1', color='red')
plt.plot(epochs, loss2, 'bo', label='Model 2', color='blue')
plt.plot(epochs, loss3, 'bo', label='Model 3', color='green')
plt.plot(epochs, loss4, 'bo', label='Model 4', color='orange')
plt.plot(epochs, val_loss1, 'b', label='', color='red')
plt.plot(epochs, val_loss2, 'b', label='', color='blue')
plt.plot(epochs, val_loss3, 'b', label='', color='green')
plt.plot(epochs, val_loss4, 'b', label='', color='orange')
plt.legend()
plt.title('Strata trenowania i walidacji')
plt.xlabel('Epoki')
plt.ylabel('Strata')
plt.legend()
clear_output()
plt.show()

# %%
accuracy1 = history1.history['accuracy']
accuracy2 = history2.history['accuracy']
accuracy3 = history3.history['accuracy']
accuracy4 = history4.history['accuracy']
val_accuracy1 = history1.history['val_accuracy']
val_accuracy2 = history2.history['val_accuracy']
val_accuracy3 = history3.history['val_accuracy']
val_accuracy4 = history4.history['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, accuracy1, 'bo', label='Model 1', color='red')
plt.plot(epochs, accuracy2, 'bo', label='Model 2', color='blue')
plt.plot(epochs, accuracy3, 'bo', label='Model 3', color='green')
plt.plot(epochs, accuracy4, 'bo', label='Model 4', color='orange')
plt.plot(epochs, val_accuracy1, 'b', label='', color='red')
plt.plot(epochs, val_accuracy2, 'b', label='', color='blue')
plt.plot(epochs, val_accuracy3, 'b', label='', color='green')
plt.plot(epochs, val_accuracy4, 'b', label='', color='orange')
plt.legend()
plt.title('Dokładność trenowania i walidacji')
plt.xlabel('Epoki')
plt.ylabel('Dokładność')
plt.legend()
clear_output()
plt.show()
